# %% [markdown]
# # web scraping using BeautifulSoup

# %% [markdown]
# Scrap data from this link: https://en.wikipedia.org/wiki/List_of_African_countries_by_area
#
# focus on the first table:
# - take rank , country and area.
# - using pandas split are into two columns: km**2 and square mi

# %%
#import neccessary libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import lxml.html as lh

# %%
#assingling link to the variable
link = 'https://en.wikipedia.org/wiki/List_of_African_countries_by_area'
page = requests.get(link)
print(page)
# Out:
# <Response [200]>

# %%
#Store the contents of the website under doc
doc = lh.fromstring(page.content)

# %%
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4]

# %%
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print ('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Rank
# "
# 2:"Country[1][2][3]
# "
# 3:"Area[a][b][4]
# "
# 4:"Notes
# "

# %%
# Since our first row is the header, data is stored on the second row onwards
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 4, the //tr data is not from our table 
    if len(T)!=4:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data[:-1])
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [54, 54, 54, 54]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
# new data frame with split value columns 
new = df["Area[a][b][4]\n"].str.split("(", n = 1, expand = True) 
  
# making separate first name column from new data frame 
df["Areakm**2"]= new[0] 
  
# making separate last name column from new data frame 
df["Areasquare mi"]= new[1] 
  
# Dropping old Name columns 
df.drop(columns =["Area[a][b][4]\n"], inplace = True)

# %%
df
# Out:
#    Rank\n                 Country[1][2][3]\n  \
# 0       1                            Algeria
# 1       2   Democratic Republic of the Congo
# 2       3                              Sudan
# 3       4                              Libya
# 4       5                               Chad
# 5       6                              Niger
# 6       7                             Angola
# 7       8                               Mali
# 8       9                       South Africa
# 9      10                           Ethiopia
# 10     11                         Mauritania
# 11     12                           Egypt[a]
# 12     13                           Tanzania
# 13     14                            Nigeria
# 14     15                            Namibia
# 15     16                         Mozambique
# 16     17                             Zambia
# 17     18                            Morocco
# 18     19                        South Sudan
# 19     20                            Somalia
# 20     21           Central African Republic
# 21     22                         Madagascar
# 22     23                           Botswana
# 23     24                              Kenya
# 24     25                           Cameroon
# 25     26                           Zimbabwe
# 26     27              Republic of the Congo
# 27     28        Ivory Coast (Côte d'Ivoire)
# 28     29                       Burkina Faso
# 29     30                              Gabon
# 30     31                             Guinea
# 31     32                              Ghana
# 32     33                             Uganda
# 33     34                            Senegal
# 34     35                            Tunisia
# 35     36                             Malawi
# 36     37                            Eritrea
# 37     38                              Benin
# 38     39                            Liberia
# 39     40                       Sierra Leone
# 40     41                               Togo
# 41     42                      Guinea-Bissau
# 42     43                            Lesotho
# 43     44                  Equatorial Guinea
# 44     45                            Burundi
# 45     46                             Rwanda
# 46     47                           Djibouti
# 47     48               Eswatini (Swaziland)
# 48     49                        Gambia, The
# 49     50                         Cape Verde
# 50     51                            Comoros
# 51     52                          Mauritius
# 52     53              São Tomé and Príncipe
# 53     54                         Seychelles
#
#                                               Notes\n       Areakm**2  \
# 0                                                      2,381,741 km2
# 1                                                      2,344,858 km2
# 2                                                      1,861,484 km2
# 3                                                      1,759,540 km2
# 4                                                      1,284,000 km2
# 5                                                      1,267,000 km2
# 6                                                      1,246,700 km2
# 7                                                      1,240,192 km2
# 8                                                      1,221,037 km2
# 9                                                      1,104,300 km2
# 10                                                     1,030,700 km2
# 11  1,010,408 km2 (390,121 sq mi) when including S...  1,001,449 km2
# 12                                                       945,203 km2
# 13                                                       923,768 km2
# 14                                                       825,418 km2
# 15                                                       801,590 km2
# 16                                                       752,614 km2
# 17  446,550 km2 (172,414 sq mi) excluding all disp...    710,850 km2
# 18                                                       644,329 km2
# 19                                                       637,657 km2
# 20                                                       622,984 km2
# 21                                                       587,041 km2
# 22                                                       581,726 km2
# 23                                                       580,367 km2
# 24                                                       475,442 km2
# 25                                                       390,757 km2
# 26                                                       342,000 km2
# 27                                                       322,460 km2
# 28                                                       274,000 km2
# 29                                                       267,668 km2
# 30                                                       245,857 km2
# 31                                                       238,534 km2
# 32                                                       236,040 km2
# 33                                                       196,723 km2
# 34                                                       163,610 km2
# 35                                                       118,484 km2
# 36                                                       117,600 km2
# 37                                                       112,622 km2
# 38                                                       111,369 km2
# 39                                                        71,740 km2
# 40                                                        56,785 km2
# 41                                                        36,125 km2
# 42                                                        30,355 km2
# 43                                                        28,051 km2
# 44                                                        27,830 km2
# 45                                                        26,798 km2
# 46                                                        23,200 km2
# 47                                                        17,364 km2
# 48                                                        10,380 km2
# 49                                                         4,033 km2
# 50  1,659 km2 excluding the disputed island of May...      2,235 km2
# 51                                                         2,040 km2
# 52                                                           964 km2
# 53                                                           451 km2
#
#      Areasquare mi
# 0   919,595 sq mi)
# 1   905,355 sq mi)
# 2   718,723 sq mi)
# 3   679,362 sq mi)
# 4   495,755 sq mi)
# 5   489,191 sq mi)
# 6   481,354 sq mi)
# 7   478,841 sq mi)
# 8   471,445 sq mi)
# 9   426,373 sq mi)
# 10  397,955 sq mi)
# 11  386,662 sq mi)
# 12  364,945 sq mi)
# 13  356,669 sq mi)
# 14  318,696 sq mi)
# 15  309,496 sq mi)
# 16  290,586 sq mi)
# 17  274,461 sq mi)
# 18  248,777 sq mi)
# 19  246,201 sq mi)
# 20  240,535 sq mi)
# 21  226,658 sq mi)
# 22  224,606 sq mi)
# 23  224,081 sq mi)
# 24  183,569 sq mi)
# 25  150,872 sq mi)
# 26  132,047 sq mi)
# 27  124,503 sq mi)
# 28  105,792 sq mi)
# 29  103,347 sq mi)
# 30   94,926 sq mi)
# 31   92,098 sq mi)
# 32   91,136 sq mi)
# 33   75,955 sq mi)
# 34   63,170 sq mi)
# 35   45,747 sq mi)
# 36   45,406 sq mi)
# 37   43,484 sq mi)
# 38   43,000 sq mi)
# 39   27,699 sq mi)
# 40   21,925 sq mi)
# 41   13,948 sq mi)
# 42   11,720 sq mi)
# 43   10,831 sq mi)
# 44   10,745 sq mi)
# 45   10,347 sq mi)
# 46    8,958 sq mi)
# 47    6,704 sq mi)
# 48    4,008 sq mi)
# 49    1,557 sq mi)
# 50      863 sq mi)
# 51      788 sq mi)
# 52      372 sq mi)
# 53      174 sq mi)
